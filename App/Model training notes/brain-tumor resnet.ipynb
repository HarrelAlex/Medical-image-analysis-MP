# %%
# MIA brain tumor project model

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True     
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
# Data loading and preprocessing

data_transforms = {
    'Training': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'Testing': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# Assigning the data loc

data_dir = 'Input/tumor_ct'


image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['Testing', 'Training']}



dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['Training', 'Testing']}

dataset_sizes = {x: len(image_datasets[x]) for x in ['Training', 'Testing']}

class_names = image_datasets['Training'].classes

# %%
#Training the model function

def train_model(model, criterion, optimizer, scheduler, num_epochs=25):

    since = time.time()

    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            
            for phase in ['Training', 'Testing']:
                if phase == 'Training':
                    model.train()  
                else:
                    model.eval()   

                running_loss = 0.0
                running_corrects = 0

                
                for inputs, labels in dataloaders[phase]:
                    inputs = inputs.to(device)
                    labels = labels.to(device)

                    
                    optimizer.zero_grad()

                    
                    with torch.set_grad_enabled(phase == 'Training'):
                        outputs = model(inputs)
                        _, preds = torch.max(outputs, 1)
                        loss = criterion(outputs, labels)

                        
                        if phase == 'Training':
                            loss.backward()
                            optimizer.step()

                   
                    running_loss += loss.item() * inputs.size(0)
                    running_corrects += torch.sum(preds == labels.data)
                if phase == 'Training':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects.double() / dataset_sizes[phase]

                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

                # deep copy the model
                if phase == 'Testing' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model

# %%
# Transfer Learning using ResNet50 and feature extraction

model_ft = models.resnet50(weights='IMAGENET1K_V1')
num_ftrs = model_ft.fc.in_features

model_ft.fc = nn.Linear(num_ftrs, len(class_names))

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)


exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
# Fitting the model and defining number of epochs

model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=50)
# Out:
# Epoch 0/49
# ----------
# Training Loss: 0.9027 Acc: 0.6571
# Testing Loss: 1.4784 Acc: 0.6447
#
# Epoch 1/49
# ----------
# Training Loss: 0.7047 Acc: 0.7418
# Testing Loss: 1.5286 Acc: 0.7513
#
# Epoch 2/49
# ----------
# Training Loss: 0.5292 Acc: 0.8132
# Testing Loss: 1.1493 Acc: 0.7234
#
# Epoch 3/49
# ----------
# Training Loss: 0.4873 Acc: 0.8286
# Testing Loss: 1.2460 Acc: 0.7640
#
# Epoch 4/49
# ----------
# Training Loss: 0.4350 Acc: 0.8491
# Testing Loss: 1.8392 Acc: 0.7208
#
# Epoch 5/49
# ----------
# Training Loss: 0.3974 Acc: 0.8641
# Testing Loss: 1.0390 Acc: 0.7995
#
# Epoch 6/49
# ----------
# Training Loss: 0.3435 Acc: 0.8864
# Testing Loss: 1.3561 Acc: 0.7386
#
# Epoch 7/49
# ----------
# Training Loss: 0.2470 Acc: 0.9185
# Testing Loss: 1.3486 Acc: 0.7513
#
# Epoch 8/49
# ----------
# Training Loss: 0.2115 Acc: 0.9303
# Testing Loss: 1.1176 Acc: 0.7640
#
# Epoch 9/49
# ----------
# Training Loss: 0.1745 Acc: 0.9408
# Testing Loss: 1.4487 Acc: 0.7563
#
# Epoch 10/49
# ----------
# Training Loss: 0.1965 Acc: 0.9321
# Testing Loss: 1.2721 Acc: 0.7665
#
# Epoch 11/49
# ----------
# Training Loss: 0.1863 Acc: 0.9348
# Testing Loss: 1.3568 Acc: 0.7563
#
# Epoch 12/49
# ----------
# Training Loss: 0.1781 Acc: 0.9369
# Testing Loss: 1.1751 Acc: 0.7792
#
# Epoch 13/49
# ----------
# Training Loss: 0.1913 Acc: 0.9366
# Testing Loss: 1.0705 Acc: 0.7766
#
# Epoch 14/49
# ----------
# Training Loss: 0.1851 Acc: 0.9369
# Testing Loss: 1.0678 Acc: 0.7817
#
# Epoch 15/49
# ----------
# Training Loss: 0.1787 Acc: 0.9321
# Testing Loss: 1.0668 Acc: 0.7817
#
# Epoch 16/49
# ----------
# Training Loss: 0.1685 Acc: 0.9443
# Testing Loss: 1.4298 Acc: 0.7589
#
# Epoch 17/49
# ----------
# Training Loss: 0.1631 Acc: 0.9453
# Testing Loss: 1.7977 Acc: 0.7538
#
# Epoch 18/49
# ----------
# Training Loss: 0.1714 Acc: 0.9383
# Testing Loss: 1.1593 Acc: 0.7690
#
# Epoch 19/49
# ----------
# Training Loss: 0.1502 Acc: 0.9484
# Testing Loss: 1.0703 Acc: 0.7843
#
# Epoch 20/49
# ----------
# Training Loss: 0.1603 Acc: 0.9443
# Testing Loss: 1.1353 Acc: 0.7843
#
# Epoch 21/49
# ----------
# Training Loss: 0.1616 Acc: 0.9481
# Testing Loss: 1.4312 Acc: 0.7665
#
# Epoch 22/49
# ----------
# Training Loss: 0.1631 Acc: 0.9460
# Testing Loss: 1.2445 Acc: 0.7817
#
# Epoch 23/49
# ----------
# Training Loss: 0.1577 Acc: 0.9463
# Testing Loss: 1.1891 Acc: 0.7843
#
# Epoch 24/49
# ----------
# Training Loss: 0.1741 Acc: 0.9422
# Testing Loss: 1.1402 Acc: 0.7716
#
# Epoch 25/49
# ----------
# Training Loss: 0.1596 Acc: 0.9443
# Testing Loss: 1.1125 Acc: 0.7792
#
# Epoch 26/49
# ----------
# Training Loss: 0.1694 Acc: 0.9408
# Testing Loss: 0.9919 Acc: 0.7843
#
# Epoch 27/49
# ----------
# Training Loss: 0.1701 Acc: 0.9425
# Testing Loss: 1.1106 Acc: 0.7817
#
# Epoch 28/49
# ----------
# Training Loss: 0.1675 Acc: 0.9463
# Testing Loss: 1.0509 Acc: 0.7868
#
# Epoch 29/49
# ----------
# Training Loss: 0.1553 Acc: 0.9516
# Testing Loss: 1.3511 Acc: 0.7690
#
# Epoch 30/49
# ----------
# Training Loss: 0.1748 Acc: 0.9394
# Testing Loss: 1.2415 Acc: 0.7766
#
# Epoch 31/49
# ----------
# Training Loss: 0.1625 Acc: 0.9474
# Testing Loss: 1.2519 Acc: 0.7665
#
# Epoch 32/49
# ----------
# Training Loss: 0.1724 Acc: 0.9436
# Testing Loss: 1.2439 Acc: 0.7766
#
# Epoch 33/49
# ----------
# Training Loss: 0.1639 Acc: 0.9443
# Testing Loss: 1.3123 Acc: 0.7665
#
# Epoch 34/49
# ----------
# Training Loss: 0.1733 Acc: 0.9436
# Testing Loss: 0.9805 Acc: 0.7792
#
# Epoch 35/49
# ----------
# Training Loss: 0.1573 Acc: 0.9463
# Testing Loss: 1.3890 Acc: 0.7741
#
# Epoch 36/49
# ----------
# Training Loss: 0.1603 Acc: 0.9456
# Testing Loss: 1.1754 Acc: 0.7843
#
# Epoch 37/49
# ----------
# Training Loss: 0.1731 Acc: 0.9436
# Testing Loss: 1.1392 Acc: 0.7766
#
# Epoch 38/49
# ----------
# Training Loss: 0.1626 Acc: 0.9422
# Testing Loss: 1.2433 Acc: 0.7716
#
# Epoch 39/49
# ----------
# Training Loss: 0.1626 Acc: 0.9512
# Testing Loss: 1.1013 Acc: 0.7792
#
# Epoch 40/49
# ----------
# Training Loss: 0.1787 Acc: 0.9397
# Testing Loss: 1.2477 Acc: 0.7817
#
# Epoch 41/49
# ----------
# Training Loss: 0.1669 Acc: 0.9460
# Testing Loss: 1.4204 Acc: 0.7665
#
# Epoch 42/49
# ----------
# Training Loss: 0.1563 Acc: 0.9495
# Testing Loss: 1.1165 Acc: 0.7766
#
# Epoch 43/49
# ----------
# Training Loss: 0.1695 Acc: 0.9474
# Testing Loss: 1.1104 Acc: 0.7792
#
# Epoch 44/49
# ----------
# Training Loss: 0.1586 Acc: 0.9502
# Testing Loss: 1.1839 Acc: 0.7868
#
# Epoch 45/49
# ----------
# Training Loss: 0.1767 Acc: 0.9401
# Testing Loss: 1.0906 Acc: 0.7868
#
# Epoch 46/49
# ----------
# Training Loss: 0.1503 Acc: 0.9498
# Testing Loss: 1.3006 Acc: 0.7741
#
# Epoch 47/49
# ----------
# Training Loss: 0.1632 Acc: 0.9449
# Testing Loss: 1.2592 Acc: 0.7817
#
# Epoch 48/49
# ----------
# Training Loss: 0.1787 Acc: 0.9397
# Testing Loss: 1.3406 Acc: 0.7665
#
# Epoch 49/49
# ----------
# Training Loss: 0.1624 Acc: 0.9443
# Testing Loss: 1.0366 Acc: 0.7817
#
# Training complete in 48m 52s
# Best val Acc: 0.799492

# %%
# saving the model for future to add in app

torch.save(model_ft.state_dict(), 'tumormod.pth')
